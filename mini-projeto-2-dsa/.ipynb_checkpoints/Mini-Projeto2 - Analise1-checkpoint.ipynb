# %% [markdown]
# # <font color='blue'>Data Science Academy - Python Fundamentos - Capítulo 9</font>
#
# ## Download: http://github.com/dsacademybr
#
# ## Mini-Projeto 2 - Análise Exploratória em Conjunto de Dados do Kaggle
#
# ## Análise 1

# %%
# Imports
import os
import subprocess
import stat
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
sns.set(style = "white")
# %matplotlib inline

# %%
# Imports
import os
import subprocess
import stat
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mat
import matplotlib.pyplot as plt
from datetime import datetime
sns.set(style="white")
# %matplotlib inline

# %%
np.__version__
# Out:
# '1.21.0'

# %%
pd.__version__
# Out:
# '1.3.0'

# %%
sns.__version__
# Out:
# '0.11.1'

# %%
mat.__version__
# Out:
# '3.5.1'

# %%
# !conda update --all
# Out:
# ^C

# %%
# Dataset
import zipfile
clean_data_path = "dataset/autos.zip"

print(zipfile.ZipFile(clean_data_path).filelist)
zf = zipfile.ZipFile(clean_data_path)
zf.open('autos.csv')
df = pd.read_csv(zf.open('autos.csv'),encoding = "utf-8")
# Out:
# [<ZipInfo filename='autos.csv' compress_type=deflate filemode='-rwxr-xr-x' file_size=67791600 compress_size=16804881>, <ZipInfo filename='__MACOSX/._autos.csv' compress_type=deflate filemode='-rwxr-xr-x' file_size=445 compress_size=330>]

# %%
df.head()
# Out:
#            dateCrawled                            name  seller offerType  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  privat     Offer
# 1  2016-03-23 10:58:45            A5_Sportback_2.7_Tdi  privat     Offer
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat     Offer
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  privat     Offer
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat     Offer
#
#    price abtest vehicleType  yearOfRegistration    gearbox  powerPS  ...  \
# 0    480   test       Other                1993    manuell        0  ...
# 1  18300   test       coupe                2011    manuell      190  ...
# 2   9800   test         suv                2004  automatik      163  ...
# 3   1500   test  kleinwagen                2001    manuell       75  ...
# 4   3600   test  kleinwagen                2008    manuell       69  ...
#
#   postalCode             lastSeen yearOfCreation yearCrawled monthOfCreation  \
# ...

# %%
df.groupby('seller').sum()
# Out:
#                  price  yearOfRegistration   powerPS    kilometer  \
# seller
# gewerblich        8100                5973       139       370000
# privat      1224300298           627966928  34368742  41229325000
#
#              postalCode  yearOfCreation  yearCrawled  NoOfDaysOnline  \
# seller
# gewerblich       146819            6048         6048              58
# privat      15793856737       632386922    632386944         2679856
#
#             NoOfHrsOnline  yearsOld  monthsOld
# seller
# gewerblich             57        75         10
# privat            3712180   4420016    1955887

# %%
df.groupby('vehicleType').sum()
# Out:
#                  price  yearOfRegistration   powerPS    kilometer  postalCode  \
# vehicleType
# Other         16752938            38999749    996971   2444575000   919691482
# andere         6981836             5811593    266020    366365000   130532193
# bus          125507617            53759209   2945320   3613435000  1340646430
# cabrio       141384651            40802037   2694535   2405725000  1093146593
# coupe        114058633            33841529   2660605   2166065000   904309258
# kleinwagen   119956354           138746243   4462955   8872855000  3419790916
# kombi        238434329           120554869   7841274   8484610000  2996870058
# limousine    314883425           168220965  10321693  11285765000  4281815784
# suv          146348615            27236707   2179508   1590300000   707200842
#
#              yearOfCreation  yearCrawled  NoOfDaysOnline  NoOfHrsOnline  \
# vehicleType
# Other              39205152     39205152          148683         230125
# ...

# %%
df.isnull().sum()
# Out:
# dateCrawled              0
# name                     0
# seller                   0
# offerType                0
# price                    0
# abtest                   0
# vehicleType              0
# yearOfRegistration       0
# gearbox                  0
# powerPS                  0
# model                    0
# kilometer                0
# monthOfRegistration      0
# fuelType               189
# brand                    0
# notRepairedDamage        0
# dateCreated              0
# postalCode               0
# lastSeen                 0
# yearOfCreation           0
# yearCrawled              0
# monthOfCreation          0
# monthCrawled             0
# NoOfDaysOnline           0
# NoOfHrsOnline            0
# yearsOld                 0
# monthsOld                0
# dtype: int64

# %%
data=df["yearOfRegistration"]

bins=np.arange(data.min(), data.max() + 1)

bins
# Out:
# array([1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920,
#        1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931,
#        1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942,
#        1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953,
#        1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964,
#        1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975,
#        1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986,
#        1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997,
#        1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008,
#        2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016])

# %% [markdown]
# ## Distribuição de Veículos com base no Ano de Registro

# %%
# Crie um Plot com a Distribuição de Veículos com base no Ano de Registro
fig, ax = plt.subplots(figsize=(6,4))
sns.histplot(df["yearOfRegistration"], color="#33cc33",kde=True, ax=ax, discrete=True)
ax.set_title('Distribuição de Veículos com base no Ano de Registro', fontsize= 15)
plt.ylabel("Densidade (KDE)", fontsize= 15)
plt.xlabel("Ano de Registro", fontsize= 15)
plt.show()

# %%
# Salvando o plot
fig.savefig("plots/Analise1/vehicle-distribution.png")

# %% [markdown]
# # Crie um Boxplot para avaliar os outliers

# %%
fig, ax = plt.subplots(figsize=(8,6))
sns.boxplot(x='vehicleType',y='price',data=df)
ax.text(5.25,27000,"Análise de Outliers",fontsize=18,color="r",ha="center", va="center")
ax.xaxis.set_label_text("Tipo de Veículo",fontdict= {'size':14})
ax.yaxis.set_label_text("Range de Preço",fontdict= {'size':14})
plt.show()

# %%
# Salvando o plot
fig.savefig("plots/Analise1/price-vehicleType-boxplot.png")

# %% [markdown]
# ## Contagem total de veículos à venda conforme o tipo de veículo

# %%
fig, axs = plt.subplots(figsize=(12,8))
ax = sns.countplot(data=df, x='vehicleType' )
ax.bar_label(ax.containers[0])
ax.set(xlabel='Tipo de Veículo',ylabel='Total de veículos para Venda')
# Out:
# [Text(0, 0, '19447'),
#  Text(0, 0, '16920'),
#  Text(0, 0, '13585'),
#  Text(0, 0, '69334'),
#  Text(0, 0, '84077'),
#  Text(0, 0, '20388'),
#  Text(0, 0, '60195'),
#  Text(0, 0, '26833'),
#  Text(0, 0, '2908')]

# %%
fig, axs = plt.subplots(figsize=(12,8))
ax = sns.countplot(data=df, x='vehicleType', palette='BuPu')
ax.bar_label(ax.containers[0])

plt.xlabel('Tipo de Veículo',fontsize=18)
plt.ylabel('Total de Veículos para venda',fontsize=16)
plt.title('Contagem de Veículos à venda por Tipo de Veículo', fontsize=18)
# Out:
# Text(0.5, 1.0, 'Contagem de Veículos à venda por Tipo de Veículo')

# %%
fig, axs = plt.subplots(figsize=(12,8))
ax = sns.catplot(x="vehicleType", data=df, kind="count", palette="BuPu", height=6, aspect=1.5)
ax.bar_label(ax.containers[0])

plt.xlabel('Tipo de Veículo',fontsize=18)
plt.ylabel('Total de Veículos para venda',fontsize=16)
plt.title('Contagem de Veículos à venda por Tipo de Veículo', fontsize=18)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\MATHEU~1.SCH\AppData\Local\Temp/ipykernel_10108/1417270722.py in <module>
#       1 fig, axs = plt.subplots(figsize=(12,8))
#       2 ax = sns.catplot(x="vehicleType", data=df, kind="count", palette="BuPu", height=6, aspect=1.5)
# ----> 3 ax.bar_label(ax.containers[0])
#       4
#       5 plt.xlabel('Tipo de Veículo',fontsize=18)
#
# AttributeError: 'FacetGrid' object has no attribute 'bar_label'

# %%
# Crie um Count Plot que mostre o número de veículos pertencentes a cada categoria

# %%
# Salvando o plot
g.savefig("plots/Analise1/count-vehicleType.png")

# %% [markdown]
# # Fim

# %% [markdown]
# ### Obrigado
#
# ### Visite o Blog da Data Science Academy - <a href="http://blog.dsacademy.com.br">Blog DSA</a>
